# %% [markdown]
# ## Conceitos importantes

# %% [markdown]
# **Text files (arquivos de texto)**: armazenam dados em formato legível por humanos, usando caracteres (letras, números, símbolos). Exemplos: .txt, .csv, .py.
# 👉 Exemplo: nome,idade\nJoão,25
#
# **Arquivos binários**: armazenam dados em formato que não é legível diretamente, pois usa código binário (0 e 1). São usados para imagens, vídeos, programas, etc. Exemplos: .jpg, .exe, .mp3.
# 👉 Exemplo: 01101000 1100101 1101100 1101100 1101111 (representa “hello”).
#
# **Text File (arquivo de texto)**: armazena dados como texto legível (caracteres), usando codificações como UTF-8. Exemplos: `.txt`, `.csv`, `.json`.
#
# **End of Line Character (EOL)**: é o caractere que indica o **fim de uma linha** em um arquivo de texto.
#   * No Windows: `\r\n`
#   * No Linux/macOS: `\n`
#
# | Termo                 | Significado               | Função principal            | Exemplo        |
# | --------------------- | ------------------------- | --------------------------- | -------------- |
# | **Separator**         | Símbolo que separa dados  | Divide valores em uma linha | `,` ou `;`     |
# | **EOL (End of Line)** | Indica o fim de uma linha | Quebra a linha no texto     | `\n` ou `\r\n` |
# | **EOF (End of File)** | Indica o fim do arquivo   | Marca que não há mais dados | Fim da leitura |

# %% [markdown]
# **Binary File (arquivo binário)**: armazena dados em **formato binário** (0s e 1s) não legível diretamente, usado por imagens, vídeos, executáveis etc. Exemplos: `.jpg`, `.exe`, `.mp4`.

# %% [markdown]
# **File**:é o arquivo em si, ou seja, o dado armazenado no disco (exemplo: dados.txt).
#
# **File object**: é o objeto criado pelo Python quando você abre um arquivo com a função open(). Ele permite ler, escrever e manipular o conteúdo do arquivo.
#
# **File vs File Object**
#
# **File**: é o arquivo em si, o que está armazenado no disco (por exemplo, dados.txt).
#
# **File Object**: é o objeto criado no Python quando você abre o arquivo com open().
# 👉 Exemplo:
# ```python
# arquivo = open("dados.txt")
# ```
# Aqui, "dados.txt" é o file, e arquivo é o file object (ou manipulador de arquivo).

# %% [markdown]
# **Reading (leitura)**: é o ato de ler o conteúdo bruto de um arquivo ou dado (por exemplo, ler todo o texto de um .txt ou os bytes de um .bin).
# Exemplo: ler "1,2,3,4" de um arquivo CSV.
#
# **Parsing (análise)**:é o processo de interpretar e estruturar esse conteúdo bruto, transformando-o em algo compreensível pelo programa.
# Exemplo: converter "1,2,3,4" em uma lista [1, 2, 3, 4].

# %% [markdown]
# | Tipo de dado     | Estrutura               | Exemplo                 | Onde é usado                      |
# | ---------------- | ----------------------- | ----------------------- | --------------------------------- |
# | Estruturado      | Fixa (tabelas)          | SQL, planilhas          | Bancos de dados relacionais       |
# | Semi-estruturado | Parcialmente organizada | JSON, XML               | Web, APIs, NoSQL                  |
# | Não estruturado  | Sem formato definido    | Imagens, textos, vídeos | Mídias, documentos, redes sociais |

# %% [markdown]
# **Data Connectivity (ou conectividade de dados)**: é a capacidade de acessar, conectar e integrar dados que estão armazenados em diferentes fontes — como bancos de dados, planilhas, APIs, ou serviços na nuvem — para usá-los em uma aplicação, análise ou sistema.

# %% [markdown]
# | Formato | Melhor para             | Estrutura            | Leveza    | Uso comum               |
# | ------- | ----------------------- | -------------------- | --------- | ----------------------- |
# | `.csv`  | Dados tabulares simples | Tabelar              | 🟢 Leve   | Análises, import/export |
# | `.json` | Dados hierárquicos      | Flexível             | 🟢 Médio  | APIs, web, configs      |
# | `.xlsx` | Planilhas formatadas    | Tabelar (com extras) | 🔴 Pesado | Relatórios, Excel       |
#
# - Para análise e automação → .csv
#
# - Para integração e APIs → .json
#
# - Para apresentação e relatórios → .xlsx

# %% [markdown]
# **Interpretador**: É o programa que lê e executa o código-fonte.
# Em vez de compilar tudo de uma vez, ele traduz e executa linha por linha.
#
# **Encoding e Decoding**
#
# São processos de conversão entre texto e bytes — o interpretador precisa disso para entender e manipular os dados.
#
# **Encoding (codificação):** Converte texto legível (caracteres) para bytes (números binários que o computador entende).
# Exemplo: `"Olá"` → `b'\xc3\x93l\xc3\xa1'` em UTF-8.
#
# **Decoding (decodificação):**: Faz o inverso — converte **bytes** → **texto legível**.
# Exemplo: `b'\xc3\x93l\xc3\xa1'` → `"Olá"`.

# %% [markdown]
# ## Importing Text Files in Python ( `open()` )

# %%
filename = "source.txt"

# %%
filename
# Out:
# 'source.txt'

# %%
file = open(filename, mode= "r")

# %%
file
# Out:
# <_io.TextIOWrapper name='source.txt' mode='r' encoding='cp1252'>

# %%
file.read()
# Out:
# 'This is the simplest plain text file!\n'

# %%
file = open(filename, mode = "r")
text = file.read()
text
# Out:
# 'This is the simplest plain text file!\n'

# %%
file.close()

# %%
file.closed
# Out:
# True
